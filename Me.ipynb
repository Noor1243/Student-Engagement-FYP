# %%
# !pip3 install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached opencv_python-4.8.0.74-cp37-abi3-win_amd64.whl.metadata (19 kB)
# ...
#    ---------------------------------------- 0.0/38.1 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.1 MB 3.4 MB/s eta 0:00:12
#     --------------------------------------- 0.8/38.1 MB 3.0 MB/s eta 0:00:13
#    - -------------------------------------- 1.3/38.1 MB 2.2 MB/s eta 0:00:17
#    -- ------------------------------------- 2.1/38.1 MB 2.7 MB/s eta 0:00:14
#    -- ------------------------------------- 2.6/38.1 MB 2.6 MB/s eta 0:00:14
#    --- ------------------------------------ 3.1/38.1 MB 2.6 MB/s eta 0:00:14
#    --- ------------------------------------ 3.7/38.1 MB 2.6 MB/s eta 0:00:14
#    ---- ----------------------------------- 4.2/38.1 MB 2.6 MB/s eta 0:00:13
#    ----- ---------------------------------- 5.0/38.1 MB 2.6 MB/s eta 0:00:13
# ...

# %%
import os

#os.chdir("backend/processing")
print("📂 Now inside:", os.getcwd())
# Out:
# 📂 Now inside: c:\Users\Dell\Desktop\engagement_analysis-main\backend\processing

# %%
# !python main_processor.py
# Out:
# ^C
# *
# *
# *
# Starting real-time engagement detection. Press 'q' to quit.
# *
# *
# *
#
# Left Iris Landmark - x: 0.3492979407310486, y: 0.6532390117645264, z: 0.03994041308760643
# Right Iris Landmark - x: 0.46113085746765137, y: 0.6415239572525024, z: 0.011979706585407257
# Left Eye Left Corner Landmark - x: 0.3288760781288147, y: 0.6575841903686523, z: 0.05386291816830635
# Left Eye Right Corner Landmark - x: 0.3703156113624573, y: 0.6522958874702454, z: 0.03491869196295738
# Left Gaze - x: 0.49281111558598467, y: -0.03108289866482955
# Right Gaze - x: 0.5234776399820148, y: -0.14273505943021225
# Final Gaze - x: 0.5081443777839998, y: 0.7065455104762395
# Left Iris Landmark - x: 0.35580646991729736, y: 0.6589899659156799, z: 0.036890387535095215
# Right Iris Landmark - x: 0.46727433800697327, y: 0.651800274848938, z: 0.006475514732301235
# Left Eye Left Corner Landmark - x: 0.33370187878608704, y: 0.6629124283790588, z: 0.052403710782527924
# ...

# %%
# !python heatmap.py
# Out:
# Raw gaze: (0.457, 0.705)
# Mapped window pos: (136, 119)
# Observed ranges - X: [0.457, 0.457], Y: [0.705, 0.705]
# Raw gaze: (0.451, 0.722)
# Mapped window pos: (135, 121)
# Observed ranges - X: [0.451, 0.457], Y: [0.705, 0.722]
# Raw gaze: (0.440, 0.721)
# Mapped window pos: (131, 121)
# Observed ranges - X: [0.440, 0.457], Y: [0.705, 0.722]
# Raw gaze: (0.431, 0.724)
# Mapped window pos: (129, 122)
# Observed ranges - X: [0.431, 0.457], Y: [0.705, 0.724]
# Raw gaze: (0.425, 0.724)
# Mapped window pos: (127, 122)
# Observed ranges - X: [0.425, 0.457], Y: [0.705, 0.724]
# Raw gaze: (0.442, 0.710)
# Mapped window pos: (132, 119)
# Observed ranges - X: [0.425, 0.457], Y: [0.705, 0.724]
# Raw gaze: (0.441, 0.712)
# Mapped window pos: (132, 120)
# Observed ranges - X: [0.425, 0.457], Y: [0.705, 0.724]
# Raw gaze: (0.451, 0.708)
# Mapped window pos: (135, 119)
# Observed ranges - X: [0.425, 0.457], Y: [0.705, 0.724]
# Raw gaze: (0.443, 0.711)
# Mapped window pos: (132, 120)
# ...

# %%
import torch
state_dict = torch.load("C:/Users/Dell/Desktop/engagement_analysis-main/backend/models/best_model_v3.pth", map_location="cpu")

for key in state_dict.keys():
    print(key, state_dict[key].shape)
# Out:
# bn_input.weight torch.Size([12])
# bn_input.bias torch.Size([12])
# bn_input.running_mean torch.Size([12])
# bn_input.running_var torch.Size([12])
# bn_input.num_batches_tracked torch.Size([])
# block1.0.weight torch.Size([64, 12])
# block1.0.bias torch.Size([64])
# block1.1.weight torch.Size([64])
# block1.1.bias torch.Size([64])
# block1.1.running_mean torch.Size([64])
# block1.1.running_var torch.Size([64])
# block1.1.num_batches_tracked torch.Size([])
# block2.0.weight torch.Size([32, 64])
# block2.0.bias torch.Size([32])
# block2.1.weight torch.Size([32])
# block2.1.bias torch.Size([32])
# block2.1.running_mean torch.Size([32])
# block2.1.running_var torch.Size([32])
# block2.1.num_batches_tracked torch.Size([])
# classifier.weight torch.Size([3, 32])
# classifier.bias torch.Size([3])
# ...
